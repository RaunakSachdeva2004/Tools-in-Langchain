# %%
# %pip install langchain langchain-core langchain-community pydantic duckduckgo-search langchain_experimental

# %% [markdown]
# ##  Built-In Tool - DuckDuckGo Search

# %%
from langchain_community.tools import DuckDuckGoSearchRun

search_tool = DuckDuckGoSearchRun()
res = search_tool.invoke('Indian premier league news')

print(res)
# Out:
# Stay updated with the latest IPL 2026 news , announcements, and match reports. Get all the information you need on IPLT20. Latest and breaking Cricket News , match peviews, reviews, player interviews of the IPL | Indian Premier League 2026 on Cricbuzz.com IPL News 2026: Get the latest Indian Premier League 2026 news , match highlights, player updates, and breaking updates throughout the tournament only on CricTracker. IPL News2026 : Get the latest IPL 2026 updates, information, match analysis and coverage. Follow Sportskeeda to get the IPL news today and for other updates on Indian Premier League IPL 2026 auction live: Latest updates from the Indian Premier League mini-auction The Indian Premier League 2026 mini-auction takes place at Abu Dhabi on Tuesday. We bring you the latest updates.

# %% [markdown]
# ## Built-In Shell Tool

# %%
from langchain_community.tools import ShellTool

shell_tool = ShellTool()

res = shell_tool.invoke('whoami')
print(res)
# Out:
# Executing command:
#  whoami
# raunak\raunak

# %% [markdown]
# ## Custom Tools

# %%
from langchain_core.tools import tool

# %%
#Step 1 - create a fucntion

def multiply(a, b):
    '''Multiply 2 numbers'''
    return a*b

# %%
# Step 2 - add type hints

def multiply (a: int, b: int) -> int:
    # multiply 2 numbers
    return a*b

# %%
# Step 3 - add tool decorator

@tool

def multiply(a: int, b:int) -> int:
    '''multiply two numbers'''
    return a*b

# %%
result = multiply.invoke({"a":3, "b":5})
print(result)
# Out:
# 15

# %%
print(multiply.name)
print(multiply.description)
print(multiply.args)
# Out:
# multiply
# multiply two numbers
# {'a': {'title': 'A', 'type': 'integer'}, 'b': {'title': 'B', 'type': 'integer'}}

# %%
print(multiply.args_schema.model_json_schema())
# Out:
# {'description': 'multiply two numbers', 'properties': {'a': {'title': 'A', 'type': 'integer'}, 'b': {'title': 'B', 'type': 'integer'}}, 'required': ['a', 'b'], 'title': 'multiply', 'type': 'object'}
